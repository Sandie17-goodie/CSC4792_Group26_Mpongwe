# %% [markdown]
# # CSC4792 Data Mining and Warehousing
# ## Group 26 — Mpongwe Town Council Dataset
# This notebook documents the extraction, cleaning, preprocessing, validation and export of data collected from official Mpongwe Town Council sources.

# %%
import pandas as pd

# %%
file_path = "../data/processed/db-unza26-csc4792-mpongwe_cdf_projects.csv"

df = pd.read_csv(file_path, sep="|")

df.head()
# Out:
#     project_id     sector     ward  \
# 0  CDF2025-001  Education  Kasamba
# 1  CDF2025-002     Health  Kasamba
# 2  CDF2025-003  Education  Kasamba
# 3  CDF2025-004  Education  Kasamba
# 4  CDF2025-005  Education  Kasamba
#
#                                         project_name approval_status  \
# 0  Construction of a 1X4 CRB at Kasamba Secondary...    Not Approved
# 1  Construction of 1 staff house and completion o...    Not Approved
# 2  Construction of 1 staff house; purchase of 80 ...    Not Approved
# 3  Construction of a Community School at Fikola a...    Not Approved
# 4  Construction of 1 staff house and purchase of ...    Not Approved
#
#              reason_not_approved  year  \
# 0             Inadequate funding  2025
# 1  It was not the first priority  2025
# 2  It was not the first priority  2025
# 3  It was not the first priority  2025
# 4  It was not the first priority  2025
#
#                                      source_document  source_url
# ...

# %%
df.shape
# Out:
# (5, 9)

# %% [markdown]
# ## Initial Data Inspection
#
# The dataset is inspected to verify its structure, data types, missing values and possible duplicate records before further processing.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   project_id           5 non-null      str
#  1   sector               5 non-null      str
#  2   ward                 5 non-null      str
#  3   project_name         5 non-null      str
#  4   approval_status      5 non-null      str
#  5   reason_not_approved  5 non-null      str
#  6   year                 5 non-null      int64
#  7   source_document      5 non-null      str
#  8   source_url           0 non-null      float64
# dtypes: float64(1), int64(1), str(7)
# memory usage: 492.0 bytes

# %%
df.isnull().sum()
# Out:
# project_id             0
# sector                 0
# ward                   0
# project_name           0
# approval_status        0
# reason_not_approved    0
# year                   0
# source_document        0
# source_url             5
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Source URL Completion

# %%
source_url = "http://www.mpongwecouncil.gov.zm/wp-content/uploads/2025/11/APPROVED-AND-UNAPPROVED-COMMUNITY-PROJECTS-2025.pdf"
df["source_url"] = df["source_url"].fillna(source_url)

# %%
df.isnull().sum()
# Out:
# project_id             0
# sector                 0
# ward                   0
# project_name           0
# approval_status        0
# reason_not_approved    0
# year                   0
# source_document        0
# source_url             0
# dtype: int64

# %% [markdown]
# ## Text Cleaning and Standardisation

# %%
text_columns = [
    "sector",
    "ward",
    "project_name",
    "approval_status",
    "reason_not_approved",
    "source_document"
]
for col in text_columns:
    df[col] = df[col].astype(str).str.strip()

# %%
df["sector"] = df["sector"].str.title()
df["ward"] = df["ward"].str.title()
df["approval_status"] = df["approval_status"].str.title()

# %%
df["project_name"] = (
    df["project_name"]
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

df["reason_not_approved"] = (
    df["reason_not_approved"]
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

# %%
df[
    [
        "project_id",
        "sector",
        "ward",
        "project_name",
        "approval_status",
        "reason_not_approved"
    ]
]
# Out:
#     project_id     sector     ward  \
# 0  CDF2025-001  Education  Kasamba
# 1  CDF2025-002     Health  Kasamba
# 2  CDF2025-003  Education  Kasamba
# 3  CDF2025-004  Education  Kasamba
# 4  CDF2025-005  Education  Kasamba
#
#                                         project_name approval_status  \
# 0  Construction of a 1X4 CRB at Kasamba Secondary...    Not Approved
# 1  Construction of 1 staff house and completion o...    Not Approved
# 2  Construction of 1 staff house; purchase of 80 ...    Not Approved
# 3  Construction of a Community School at Fikola a...    Not Approved
# 4  Construction of 1 staff house and purchase of ...    Not Approved
#
#              reason_not_approved
# 0             Inadequate funding
# 1  It was not the first priority
# 2  It was not the first priority
# 3  It was not the first priority
# 4  It was not the first priority

# %% [markdown]
# ## Data Validation
#
# The cleaned sample is validated for duplicate records, missing values, consistent categorical values, and expected data types before additional records are added.

# %%
df.duplicated().sum()
df.isnull().sum()
df["sector"].value_counts()
df["ward"].value_counts()
df["approval_status"].value_counts()
# Out:
# approval_status
# Not Approved    5
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["sector"].value_counts()
# Out:
# sector
# Education    4
# Health       1
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# project_id                str
# sector                    str
# ward                      str
# project_name              str
# approval_status           str
# reason_not_approved       str
# year                    int64
# source_document           str
# source_url             object
# dtype: object

# %% [markdown]
# Add this Markdown cell:
# ## Export Cleaned Sample

# %%
output_path = "../data/processed/db-unza26-csc4792-mpongwe_cdf_projects.csv"

# %%
df.to_csv(
    output_path,
    sep="|",
    index=False
)

# %%
check_df = pd.read_csv(output_path, sep="|")

check_df.head()

# %%
check_df.shape
# Out:
# (5, 9)

# %% [markdown]
# ## PDF Extraction Test
# The original 2025 Mpongwe CDF document is tested to determine whether its text can be extracted programmatically before processing the complete dataset.

# %%
# %pip install pdfplumber
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.6 MB 645.0 kB/s eta 0:00:10
#    ---- ----------------------------------- 0.8/6.6 MB 854.3 kB/s eta 0:00:07
#    ------ --------------------------------- 1.0/6.6 MB 962.6 kB/s eta 0:00:06
#    ------- -------------------------------- 1.3/6.6 MB 1.0 MB/s eta 0:00:06
#    --------- ------------------------------ 1.6/6.6 MB 987.3 kB/s eta 0:00:06
#    --------- ------------------------------ 1.6/6.6 MB 987.3 kB/s eta 0:00:06
#    ----------- ---------------------------- 1.8/6.6 MB 961.6 kB/s eta 0:00:05
# ...

# %%
import pdfplumber

# %%
pdf_path = "../data/raw/mpongwe_cdf_projects_2025.pdf"

# %%
with pdfplumber.open(pdf_path) as pdf:
    print("Number of pages:", len(pdf.pages))
# Out:
# Number of pages: 9

# %%
with pdfplumber.open(pdf_path) as pdf:
    first_page_text = pdf.pages[0].extract_text()

print(first_page_text)
# Out:
# MINISTRY OF LOCAL GOVERNMENT AND RURAL DEVELOPMENT - MPONGWE
# TOWN COUNCIL
# COMMUNITY PROJECTS
# MPONGWE CONSTITUENCY 2025 APPROVED AND NOT APPROVED CDF PROJECTS
# Project Name/ Sector Ward Approved Not Approved
# No. Description
# 1 Construction of a Education Kasamba Inadequate Funding
# 1X4 CRB at
# Kasamba
# Secondary
# School with
# laborotory;purch
# ase of 200
# desks,one staff
# house and solar
# powered
# borehole
# 2 Construction of 1 Health Kasamba It was not the first
# staff house and priority
# completion of 1
# staff house at
# Kasamba Rural
# Health Center
# 3 Construction of 1 Education Kasamba It was not the first
# staff house; priority
# purchase of 80
# desks and solar
# powered
# borehole at
# Mikumbi
# primary School
# 4 Construction of a Education Kasamba It was not the first
# Community priority
# School at Fikola
# area.
# 5 Construction of 1 Education Kasamba It was not the first
# staff house and priority
# purchase of 80
# desks at
# Minkoyo
# ...
